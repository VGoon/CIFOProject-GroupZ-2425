# %%
from library.algorithms.genetic_algorithms.algorithm import genetic_algorithm
from library.wedding_ga_solution import WeddingGASolution
from library.algorithms.genetic_algorithms.selection import fitness_proportionate_selection, ranking_selection, tournament_selection
from library.algorithms.genetic_algorithms.crossover import cycle_crossover, order_crossover, partially_matched_crossover
from library.algorithms.genetic_algorithms.mutation import scramble_mutation, inversion_mutation, tableswap_mutation

POP_SIZE = 50

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution_scramble_cross = genetic_algorithm(
    initial_population=initial_population,
    max_gen = 30,
    selection_algorithm=fitness_proportionate_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=ranking_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=tournament_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = inversion_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=fitness_proportionate_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = inversion_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=ranking_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = inversion_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=tournament_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = tableswap_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=fitness_proportionate_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = tableswap_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=ranking_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = tableswap_mutation,
        crossover_function = cycle_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=tournament_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = order_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=fitness_proportionate_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = order_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=ranking_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = order_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=tournament_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = partially_matched_crossover
    )
    for _ in range(POP_SIZE)
]
ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen=30,
    selection_algorithm=fitness_proportionate_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = partially_matched_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=ranking_selection,
    maximization=True,
    verbose=True
)

# %%
initial_population = [
    WeddingGASolution(        
        mutation_function = scramble_mutation,
        crossover_function = partially_matched_crossover
    )
    for _ in range(POP_SIZE)
]

ga_solution = genetic_algorithm(
    initial_population=initial_population,
    max_gen =30,
    selection_algorithm=tournament_selection,
    maximization=True,
    verbose=True
)
